# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Jun  7 13:12:58 2021

@author: rajeev
"""

import cv2
import matplotlib.pyplot as plt

# %%
img  = cv2.imread('Quotefancy.jpg')
plt.imshow(img) #by default in bgr => inverted image
# cv2.imshow('Image',img) will not work in jupyter

# %%
# switch channel
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
# cv2.COLOR_BGR2RGB,GRAYSCALE,etc
plt.imshow(img)

# %%
print(img)# 3 channels with (rgb gradient value)
img.shape
# Out:
# [[[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]
#
#  ...
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]]
# (320, 320, 3)

# %%
# cap = cv2.VideoCapture(0)
# while True:
#     ret,frame = cap.read()
#     if ret == False:
#         continue
        
#     cv2.imshow("Video Frame",frame)

#     key_pressed = cv2.waitkey(1) & 0xFF
#     if key_pressed == ord('q'):
#         break
